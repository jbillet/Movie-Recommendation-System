# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_rows', 500)
from scipy.stats import chi2_contingency
from scipy.stats import chi2
import seaborn as sns

# %%
df_links = pd.read_csv('links.csv')
df_movies = pd.read_csv('movies.csv')
df_tags = pd.read_csv('tags.csv')
df_ratings = pd.read_csv('ratings.csv')

# %%
df_links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
#merge df_movies and df_ratings
df_movies = df_ratings.merge(df_movies,on='movieId', how='left')
df_movies.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
df_movies.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# title        0
# genres       0
# dtype: int64

# %%
#drop timestamp column
df_movies = df_movies.drop(columns='timestamp')

# %%
#split year and title from title column
df_movies['movie_year']=df_movies['title'].apply(lambda x: x.split(" ")[-1])

# %%
df_movies.head()
# Out:
#    userId  movieId  rating                        title  \
# 0       1        1     4.0             Toy Story (1995)
# 1       1        3     4.0      Grumpier Old Men (1995)
# 2       1        6     4.0                  Heat (1995)
# 3       1       47     5.0  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0   Usual Suspects, The (1995)
#
#                                         genres movie_year
# 0  Adventure|Animation|Children|Comedy|Fantasy     (1995)
# 1                               Comedy|Romance     (1995)
# 2                        Action|Crime|Thriller     (1995)
# 3                             Mystery|Thriller     (1995)
# 4                       Crime|Mystery|Thriller     (1995)

# %%
#remove parenthesis from movie_year column 
df_movies['movie_year'] = df_movies['movie_year'].map(lambda x: x.lstrip('(').rstrip(')'))
df_movies
# Out:
#         userId  movieId  rating                           title  \
# 0            1        1     4.0                Toy Story (1995)
# 1            1        3     4.0         Grumpier Old Men (1995)
# 2            1        6     4.0                     Heat (1995)
# 3            1       47     5.0     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0      Usual Suspects, The (1995)
# ...        ...      ...     ...                             ...
# 100831     610   166534     4.0                    Split (2017)
# 100832     610   168248     5.0   John Wick: Chapter Two (2017)
# 100833     610   168250     5.0                  Get Out (2017)
# 100834     610   168252     5.0                    Logan (2017)
# 100835     610   170875     3.0  The Fate of the Furious (2017)
#
#                                              genres movie_year
# 0       Adventure|Animation|Children|Comedy|Fantasy       1995
# 1                                    Comedy|Romance       1995
# 2                             Action|Crime|Thriller       1995
# 3                                  Mystery|Thriller       1995
# 4                            Crime|Mystery|Thriller       1995
# ...                                             ...        ...
# 100831                        Drama|Horror|Thriller       2017
# 100832                        Action|Crime|Thriller       2017
# 100833                                       Horror       2017
# 100834                                Action|Sci-Fi       2017
# 100835                  Action|Crime|Drama|Thriller       2017
#
# [100836 rows x 6 columns]

# %% [markdown]
# # EDA

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100836 entries, 0 to 100835
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   userId      100836 non-null  int64
#  1   movieId     100836 non-null  int64
#  2   rating      100836 non-null  float64
#  3   title       100836 non-null  object
#  4   genres      100836 non-null  object
#  5   movie_year  100836 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 5.4+ MB

# %%
#descriptive statistics for movie ratings
df_movies['rating'].describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
df_movies.rating.value_counts().sort_index(ascending=False)
# Out:
# 5.0    13211
# 4.5     8551
# 4.0    26818
# 3.5    13136
# 3.0    20047
# 2.5     5550
# 2.0     7551
# 1.5     1791
# 1.0     2811
# 0.5     1370
# Name: rating, dtype: int64

# %%
#bar chart of ratings in dataset
fig, ax = plt.subplots()
df_movies['rating'].value_counts().sort_index(ascending=True).plot(kind = 'bar')
ax.set_ylabel('Frequency')
ax.set_xlabel('Ratings')
ax.set_title('Frequency of Ratings by Users')
plt.show()

# %%
#descriptive statistics for how many users reviewing movies and how many reviews they're each providing
df_movies['userId'].value_counts().describe()
# Out:
# count     610.000000
# mean      165.304918
# std       269.480584
# min        20.000000
# 25%        35.000000
# 50%        70.500000
# 75%       168.000000
# max      2698.000000
# Name: userId, dtype: float64

# %%
#unique movies
len(df_movies['movieId'].unique())
# Out:
# 9724

# %% [markdown]
# ### Hypothesis Testing

# %%
chi_sq = df_movies.groupby('rating')['genres'].value_counts()
chi_sq2 = chi_sq.unstack()
chi_sq2.fillna(0,inplace = True)
chi_sq2
# Out:
# genres  (no genres listed)  Action  Action|Adventure  \
# rating
# 0.5                    2.0     4.0               6.0
# 1.0                    2.0    13.0              13.0
# 1.5                    0.0     6.0              11.0
# 2.0                    2.0    31.0              39.0
# 2.5                    6.0    13.0              23.0
# 3.0                    6.0    51.0              68.0
# 3.5                    6.0    22.0              67.0
# 4.0                    8.0    27.0             167.0
# 4.5                    8.0    11.0              45.0
# 5.0                    7.0     8.0             116.0
#
# genres  Action|Adventure|Animation  Action|Adventure|Animation|Children  \
# rating
# 0.5                            0.0                                  1.0
# 1.0                            0.0                                  1.0
# 1.5                            0.0                                  1.0
# 2.0                            5.0                                  1.0
# 2.5                            2.0                                  2.0
# 3.0                            7.0                                  8.0
# 3.5                            6.0                                  8.0
# 4.0                           14.0                                 13.0
# 4.5                            5.0                                  2.0
# 5.0                            3.0                                  2.0
#
# genres  Action|Adventure|Animation|Children|Comedy  \
# rating
# 0.5                                            1.0
# 1.0                                            1.0
# 1.5                                            0.0
# 2.0                                            5.0
# 2.5                                            9.0
# 3.0                                           20.0
# 3.5                                           32.0
# 4.0                                           63.0
# 4.5                                           30.0
# 5.0                                           17.0
#
# genres  Action|Adventure|Animation|Children|Comedy|Fantasy  \
# rating
# 0.5                                                   0.0
# 1.0                                                   1.0
# 1.5                                                   0.0
# 2.0                                                   0.0
# 2.5                                                   3.0
# 3.0                                                   7.0
# 3.5                                                   7.0
# 4.0                                                  12.0
# 4.5                                                   5.0
# 5.0                                                   5.0
#
# genres  Action|Adventure|Animation|Children|Comedy|IMAX  \
# rating
# 0.5                                                 0.0
# 1.0                                                 1.0
# 1.5                                                 0.0
# 2.0                                                 2.0
# 2.5                                                 1.0
# 3.0                                                 7.0
# 3.5                                                 9.0
# 4.0                                                 5.0
# 4.5                                                 1.0
# 5.0                                                 4.0
#
# genres  Action|Adventure|Animation|Children|Comedy|Romance  \
# rating
# 0.5                                                   2.0
# 1.0                                                   2.0
# 1.5                                                   1.0
# 2.0                                                   0.0
# 2.5                                                   1.0
# 3.0                                                   2.0
# 3.5                                                   1.0
# 4.0                                                   5.0
# 4.5                                                   0.0
# 5.0                                                   0.0
#
# genres  Action|Adventure|Animation|Children|Comedy|Sci-Fi  ...  \
# rating                                                     ...
# 0.5                                                   1.0  ...
# 1.0                                                   0.0  ...
# 1.5                                                   3.0  ...
# 2.0                                                   2.0  ...
# 2.5                                                   0.0  ...
# 3.0                                                   3.0  ...
# 3.5                                                   4.0  ...
# 4.0                                                   5.0  ...
# 4.5                                                   1.0  ...
# 5.0                                                   0.0  ...
#
# genres  Romance|Thriller  Romance|War  Romance|Western  Sci-Fi  Sci-Fi|IMAX  \
# rating
# 0.5                  1.0          0.0              0.0     7.0          2.0
# 1.0                  0.0          0.0              0.0     5.0          0.0
# 1.5                  1.0          0.0              0.0     6.0          0.0
# 2.0                  3.0          0.0              0.0     9.0          0.0
# 2.5                  6.0          1.0              1.0     8.0          1.0
# 3.0                  3.0          1.0              3.0    25.0         14.0
# 3.5                  3.0          0.0              2.0    18.0         11.0
# 4.0                  2.0          0.0              0.0    36.0         12.0
# 4.5                  1.0          0.0              0.0    14.0         11.0
# 5.0                  2.0          0.0              0.0    14.0         22.0
#
# genres  Sci-Fi|Thriller  Sci-Fi|Thriller|IMAX  Thriller  War  Western
# rating
# 0.5                 1.0                   0.0       7.0  0.0      0.0
# 1.0                 3.0                   0.0      25.0  0.0      5.0
# 1.5                 4.0                   0.0      12.0  0.0      0.0
# 2.0                14.0                   0.0      45.0  0.0     10.0
# 2.5                 7.0                   1.0      26.0  0.0      3.0
# 3.0                25.0                   1.0     157.0  5.0     35.0
# 3.5                23.0                   3.0      70.0  0.0     12.0
# 4.0                19.0                   6.0     177.0  3.0     49.0
# 4.5                12.0                   1.0      37.0  0.0     16.0
# 5.0                 8.0                   0.0      72.0  1.0     21.0
#
# [10 rows x 951 columns]

# %%
# contingency table
stat, p, dof, expected = chi2_contingency(chi_sq2)
print(expected)
#interpret test-statistic
prob = 0.95
critical = chi2.ppf(prob, dof)
print('probability=%.3f, critical=%.3f, stat=%.3f)' % (prob, critical, stat))
if abs(stat) >= critical:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
#interpret p-value
alpha= 1-prob
print('signigicance=%.3f, p=%.3f,' % (alpha, p))
if p <= alpha:
    print('Dependent (reject H0)')
else: 
    print('Independent (fail to reject)')
# Out:
# [[6.38561625e-01 2.52707366e+00 7.54046174e+00 ... 8.53227022e+00
#   1.22277758e-01 2.05154905e+00]
#  [1.31021659e+00 5.18511246e+00 1.54717065e+01 ... 1.75067238e+01
#   2.50892538e-01 4.20941926e+00]
#  [8.34791146e-01 3.30364156e+00 9.85764013e+00 ... 1.11542306e+01
#   1.59853624e-01 2.68198858e+00]
#  ...
#  [1.24999603e+01 4.94679281e+01 1.47605915e+02 ... 1.67020747e+02
#   2.39360943e+00 4.01594470e+01]
#  [3.98564997e+00 1.57729977e+01 4.70645900e+01 ... 5.32550676e+01
#   7.63209568e-01 1.28049605e+01]
#  [6.15769170e+00 2.43687374e+01 7.27131679e+01 ... 8.22772423e+01
#   1.17913245e+00 1.97832223e+01]]
# probability=0.950, critical=8766.224, stat=21897.886)
# Dependent (reject H0)
# signigicance=0.050, p=0.000,
# Dependent (reject H0)

# %%
df_movies.head()
# Out:
#    userId  movieId  rating                        title  \
# 0       1        1     4.0             Toy Story (1995)
# 1       1        3     4.0      Grumpier Old Men (1995)
# 2       1        6     4.0                  Heat (1995)
# 3       1       47     5.0  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0   Usual Suspects, The (1995)
#
#                                         genres movie_year
# 0  Adventure|Animation|Children|Comedy|Fantasy       1995
# 1                               Comedy|Romance       1995
# 2                        Action|Crime|Thriller       1995
# 3                             Mystery|Thriller       1995
# 4                       Crime|Mystery|Thriller       1995

# %% [markdown]
# - Since the P-value is under 0.05 we can reject the null hypothesis

# %% [markdown]
# ## Surprise

# %%
df_ratings = df_ratings.drop(columns='timestamp')

# %%
from surprise import Reader, Dataset
reader = Reader()
data = Dataset.load_from_df(df_ratings, reader)
