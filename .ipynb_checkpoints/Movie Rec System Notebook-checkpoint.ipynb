# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_rows', 500)
from pyspark.sql import SparkSession
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# %%
df_links = pd.read_csv('links.csv')
df_movies = pd.read_csv('movies.csv')
df_tags = pd.read_csv('tags.csv')
df_ratings = pd.read_csv('ratings.csv')

# %%
df_links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
#merge df_movies and df_ratings
df_movies = df_ratings.merge(df_movies,on='movieId', how='left')
df_movies.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
df_movies.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# title        0
# genres       0
# dtype: int64

# %%
#drop timestamp column
df_movies = df_movies.drop(columns='timestamp')

# %%
#split year and title from title column
df_movies['movie_year']=df_movies['title'].apply(lambda x: x.split(" ")[-1])

# %%
df_movies.head()
# Out:
#    userId  movieId  rating                        title  \
# 0       1        1     4.0             Toy Story (1995)
# 1       1        3     4.0      Grumpier Old Men (1995)
# 2       1        6     4.0                  Heat (1995)
# 3       1       47     5.0  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0   Usual Suspects, The (1995)
#
#                                         genres movie_year
# 0  Adventure|Animation|Children|Comedy|Fantasy     (1995)
# 1                               Comedy|Romance     (1995)
# 2                        Action|Crime|Thriller     (1995)
# 3                             Mystery|Thriller     (1995)
# 4                       Crime|Mystery|Thriller     (1995)

# %%
#remove parenthesis from movie_year column 
df_movies['movie_year'] = df_movies['movie_year'].map(lambda x: x.lstrip('(').rstrip(')'))
df_movies
# Out:
#         userId  movieId  rating                           title  \
# 0            1        1     4.0                Toy Story (1995)
# 1            1        3     4.0         Grumpier Old Men (1995)
# 2            1        6     4.0                     Heat (1995)
# 3            1       47     5.0     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0      Usual Suspects, The (1995)
# ...        ...      ...     ...                             ...
# 100831     610   166534     4.0                    Split (2017)
# 100832     610   168248     5.0   John Wick: Chapter Two (2017)
# 100833     610   168250     5.0                  Get Out (2017)
# 100834     610   168252     5.0                    Logan (2017)
# 100835     610   170875     3.0  The Fate of the Furious (2017)
#
#                                              genres movie_year
# 0       Adventure|Animation|Children|Comedy|Fantasy       1995
# 1                                    Comedy|Romance       1995
# 2                             Action|Crime|Thriller       1995
# 3                                  Mystery|Thriller       1995
# 4                            Crime|Mystery|Thriller       1995
# ...                                             ...        ...
# 100831                        Drama|Horror|Thriller       2017
# 100832                        Action|Crime|Thriller       2017
# 100833                                       Horror       2017
# 100834                                Action|Sci-Fi       2017
# 100835                  Action|Crime|Drama|Thriller       2017
#
# [100836 rows x 6 columns]

# %%
df_movies = df_movies.join(df_movies.pop('genres').str.get_dummies('|'))

# %% [markdown]
# # EDA

# %%
ratings_data = pd.DataFrame(df_movies.groupby('title')['rating'].mean())

# %%
ratings_data['rating_count'] = pd.DataFrame(df_movies.groupby('title')['rating'].count())

# %%
ratings_data.head()
# Out:
#                                          rating  rating_count
# title
# '71 (2014)                                  4.0             1
# 'Hellboy': The Seeds of Creation (2004)     4.0             1
# 'Round Midnight (1986)                      3.5             2
# 'Salem's Lot (2004)                         5.0             1
# 'Til There Was You (1997)                   4.0             2

# %%
plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
ratings_data['rating'].hist(bins=50)

# %%
plt.scatter('rating', 'rating_count', data=ratings_data)

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100836 entries, 0 to 100835
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   userId              100836 non-null  int64
#  1   movieId             100836 non-null  int64
#  2   rating              100836 non-null  float64
#  3   title               100836 non-null  object
#  4   movie_year          100836 non-null  object
#  5   (no genres listed)  100836 non-null  int64
#  6   Action              100836 non-null  int64
#  7   Adventure           100836 non-null  int64
#  8   Animation           100836 non-null  int64
#  9   Children            100836 non-null  int64
#  10  Comedy              100836 non-null  int64
#  11  Crime               100836 non-null  int64
#  12  Documentary         100836 non-null  int64
#  13  Drama               100836 non-null  int64
#  14  Fantasy             100836 non-null  int64
#  15  Film-Noir           100836 non-null  int64
#  16  Horror              100836 non-null  int64
#  17  IMAX                100836 non-null  int64
#  18  Musical             100836 non-null  int64
#  19  Mystery             100836 non-null  int64
#  20  Romance             100836 non-null  int64
#  21  Sci-Fi              100836 non-null  int64
#  22  Thriller            100836 non-null  int64
#  23  War                 100836 non-null  int64
#  24  Western             100836 non-null  int64
# dtypes: float64(1), int64(22), object(2)
# memory usage: 22.5+ MB

# %%
#descriptive statistics for movie ratings
df_movies['rating'].describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
df_movies.rating.value_counts().sort_index(ascending=False)
# Out:
# 5.0    13211
# 4.5     8551
# 4.0    26818
# 3.5    13136
# 3.0    20047
# 2.5     5550
# 2.0     7551
# 1.5     1791
# 1.0     2811
# 0.5     1370
# Name: rating, dtype: int64

# %%
#bar chart of ratings in dataset
df_movies['rating'].value_counts().sort_index(ascending=True).plot(kind = 'bar')

# %%
#descriptive statistics for how many users reviewing movies and how many reviews they're each providing
df_movies['userId'].value_counts().describe()
# Out:
# count     610.000000
# mean      165.304918
# std       269.480584
# min        20.000000
# 25%        35.000000
# 50%        70.500000
# 75%       168.000000
# max      2698.000000
# Name: userId, dtype: float64

# %%
#unique movies
len(df_movies['movieId'].unique())
# Out:
# 9724

# %%
df_movies['Action'].value_counts()
# Out:
# 0    70201
# 1    30635
# Name: Action, dtype: int64

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100836 entries, 0 to 100835
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   userId              100836 non-null  int64
#  1   movieId             100836 non-null  int64
#  2   rating              100836 non-null  float64
#  3   title               100836 non-null  object
#  4   movie_year          100836 non-null  object
#  5   (no genres listed)  100836 non-null  int64
#  6   Action              100836 non-null  int64
#  7   Adventure           100836 non-null  int64
#  8   Animation           100836 non-null  int64
#  9   Children            100836 non-null  int64
#  10  Comedy              100836 non-null  int64
#  11  Crime               100836 non-null  int64
#  12  Documentary         100836 non-null  int64
#  13  Drama               100836 non-null  int64
#  14  Fantasy             100836 non-null  int64
#  15  Film-Noir           100836 non-null  int64
#  16  Horror              100836 non-null  int64
#  17  IMAX                100836 non-null  int64
#  18  Musical             100836 non-null  int64
#  19  Mystery             100836 non-null  int64
#  20  Romance             100836 non-null  int64
#  21  Sci-Fi              100836 non-null  int64
#  22  Thriller            100836 non-null  int64
#  23  War                 100836 non-null  int64
#  24  Western             100836 non-null  int64
# dtypes: float64(1), int64(22), object(2)
# memory usage: 22.5+ MB

# %%
action = (df_movies['Action'].values == 1).sum()
adventure = (df_movies['Adventure'].values == 1).sum()
animation = (df_movies['Animation'].values == 1).sum()
children = (df_movies['Children'].values == 1).sum()
comedy = (df_movies['Comedy'].values == 1).sum()
crime = (df_movies['Crime'].values == 1).sum()
documentary = (df_movies['Documentary'].values == 1).sum()
drama = (df_movies['Drama'].values == 1).sum()
fantasy = (df_movies['Fantasy'].values == 1).sum()
film_noir = (df_movies['Film-Noir'].values == 1).sum()
horror = (df_movies['Horror'].values == 1).sum()
imax = (df_movies['IMAX'].values == 1).sum()
musical = (df_movies['Musical'].values == 1).sum()
mystery = (df_movies['Mystery'].values == 1).sum()
romance = (df_movies['Romance'].values == 1).sum()
sci_fi = (df_movies['Sci-Fi'].values == 1).sum()
thriller = (df_movies['Thriller'].values == 1).sum()
war = (df_movies['War'].values == 1).sum()
western = (df_movies['Western'].values == 1).sum()

# %%
print("Action:", action)
print("Adventure:", adventure)
print("Animation:", animation)
print("Children :", children)
print("Comedy:", comedy)
print("Crime:", crime)
print("Documentary:", documentary)
print("Drama:", drama)
print("Fantasy:", fantasy)
print("Film-Noir:", film_noir)
print("Horror:", horror)
print("IMAX:", imax)
print("Musical:", musical)
print("Mystery:", mystery)
print("Romance:", romance)
print("Sci-Fi:", sci_fi)
print("Thriller:", thriller)
print("War:", war)
print("Western:", western)
# Out:
# Action: 30635
# Adventure: 24161
# Animation: 6988
# Children : 9208
# Comedy: 39053
# Crime: 16681
# Documentary: 1219
# Drama: 41928
# Fantasy: 11834
# Film-Noir: 870
# Horror: 7291
# IMAX: 4145
# Musical: 4138
# Mystery: 7674
# Romance: 18124
# Sci-Fi: 17243
# Thriller: 26452
# War: 4859
# Western: 1930

# %% [markdown]
# # Recommendation with Surprise

# %%
df_ratings = df_ratings.drop(columns='timestamp')

# %%
# !Pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /Users/joeybillet/anaconda3/lib/python3.7/site-packages (1.1.1)
# Requirement already satisfied: six>=1.10.0 in /Users/joeybillet/anaconda3/lib/python3.7/site-packages (from scikit-surprise) (1.14.0)
# Requirement already satisfied: joblib>=0.11 in /Users/joeybillet/anaconda3/lib/python3.7/site-packages (from scikit-surprise) (0.14.1)
# Requirement already satisfied: numpy>=1.11.2 in /Users/joeybillet/anaconda3/lib/python3.7/site-packages (from scikit-surprise) (1.18.1)
# Requirement already satisfied: scipy>=1.0.0 in /Users/joeybillet/anaconda3/lib/python3.7/site-packages (from scikit-surprise) (1.4.1)

# %%
from surprise import Reader, Dataset
from surprise.model_selection import train_test_split
reader = Reader()
data = Dataset.load_from_df(df_ratings, reader)

# %%
trainset, testset = train_test_split(data, test_size=0.2)

# %%
from surprise.prediction_algorithms import knns
from surprise.similarities import cosine, msd, pearson
from surprise import accuracy

# %%
print('Number of users: ', trainset.n_users, '\n')
print('Number of items: ', trainset.n_items, '\n')
# Out:
# Number of users:  610
#
# Number of items:  8986

# %%
basic = knns.KNNBasic()
basic.fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
predictions = basic.test(testset)
print(accuracy.rmse(predictions))
print(accuracy.mae(predictions))
# Out:
# RMSE: 0.9471
# 0.9470790085920231
# MAE:  0.7259
# 0.7259385998190357

# %%
sim_cos = {'name':'cosine', 'user_based':True}

# %%
cosine = knns.KNNBasic(sim_options=sim_cos)
cosine.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
predictions = cosine.test(testset)
print(accuracy.rmse(predictions))
print(accuracy.mae(predictions))
# Out:
# RMSE: 0.9717
# 0.9716736044668927
# MAE:  0.7485
# 0.7485108920489096

# %%
sim_pearson = {'name':'pearson', 'user_based':True}

# %%
pearson = knns.KNNBasic(sim_options=sim_pearson)
pearson.fit(trainset)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
predictions = pearson.test(testset)
print(accuracy.rmse(predictions))
print(accuracy.mae(predictions))
# Out:
# RMSE: 0.9714
# 0.9714109008291633
# MAE:  0.7496
# 0.7496301847927409

# %% [markdown]
# # SVD

# %%
from surprise.prediction_algorithms import SVD
from surprise.model_selection import GridSearchCV

# %%
param_grid = {'n_factors':[20, 60, 100],'n_epochs': [5, 7, 9],'reg_all': [0.2, 0.4, 0.6, 0.8]}

# %%
gs_svd = GridSearchCV(SVD,param_grid=param_grid,n_jobs = -1,joblib_verbose=5)

# %%
gs_svd.fit(data)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:  7.2min finished

# %%
print(gs_svd.best_score)
print(gs_svd.best_params)
# Out:
# {'rmse': 0.8836935943427553, 'mae': 0.6824983591900163}
# {'rmse': {'n_factors': 20, 'n_epochs': 9, 'reg_all': 0.2}, 'mae': {'n_factors': 20, 'n_epochs': 9, 'reg_all': 0.2}}

# %% [markdown]
# # Recommendation System for Similarly Rated Movies

# %%
#create pivot table of movie ratings
movie_ratings_df = df_movies.pivot_table(index='userId', columns='title', values='rating')

# %%
movie_ratings_df.head()
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
#
# title   *batteries not included (1987)  ...  Zulu (2013)  [REC] (2007)  \
# userId                                  ...
# 1                                  NaN  ...          NaN           NaN
# 2                                  NaN  ...          NaN           NaN
# 3                                  NaN  ...          NaN           NaN
# 4                                  NaN  ...          NaN           NaN
# 5                                  NaN  ...          NaN           NaN
#
# title   [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userId
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 4                 NaN                      NaN
# 5                 NaN                      NaN
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
#
# title   eXistenZ (1999)  xXx (2002)  xXx: State of the Union (2005)  \
# userId
# 1                   NaN         NaN                             NaN
# 2                   NaN         NaN                             NaN
# 3                   NaN         NaN                             NaN
# 4                   NaN         NaN                             NaN
# 5                   NaN         NaN                             NaN
#
# title   ¡Three Amigos! (1986)  À nous la liberté (Freedom for Us) (1931)
# userId
# 1                         4.0                                        NaN
# 2                         NaN                                        NaN
# 3                         NaN                                        NaN
# 4                         NaN                                        NaN
# 5                         NaN                                        NaN
#
# [5 rows x 9719 columns]

# %% [markdown]
# ### Find Recommendation for Pulp Fiction

# %%
#Find user ratings for 'Pulp Fiction'
pulp_fiction = movie_ratings_df['Pulp Fiction (1994)']

# %%
pulp_fiction.head()
# Out:
# userId
# 1    3.0
# 2    NaN
# 3    NaN
# 4    1.0
# 5    5.0
# Name: Pulp Fiction (1994), dtype: float64

# %%
movies_like_pulp_fiction = movie_ratings_df.corrwith(pulp_fiction)

corr_pulp_fiction = pd.DataFrame(movies_like_pulp_fiction, columns=['Correlation'])
corr_pulp_fiction.dropna(inplace=True)
corr_pulp_fiction.head()
# Out:
# /Users/joeybillet/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /Users/joeybillet/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#                                 Correlation
# title
# 'burbs, The (1989)                -0.187323
# (500) Days of Summer (2009)       -0.044034
# *batteries not included (1987)    -0.738549
# ...And Justice for All (1979)     -0.188982
# 10 Cent Pistol (2015)              1.000000

# %%
corr_pulp_fiction = corr_pulp_fiction.join(ratings_data['rating_count'])
corr_pulp_fiction.head()
# Out:
#                                 Correlation  rating_count
# title
# 'burbs, The (1989)                -0.187323            17
# (500) Days of Summer (2009)       -0.044034            42
# *batteries not included (1987)    -0.738549             7
# ...And Justice for All (1979)     -0.188982             3
# 10 Cent Pistol (2015)              1.000000             2

# %%
corr_pulp_fiction[corr_pulp_fiction['rating_count']>100].sort_values('Correlation', ascending=False).head(25)
# Out:
#                                                     Correlation  rating_count
# title
# Pulp Fiction (1994)                                    1.000000           307
# Fight Club (1999)                                      0.543465           218
# Kill Bill: Vol. 1 (2003)                               0.504147           131
# Trainspotting (1996)                                   0.437714           102
# Kill Bill: Vol. 2 (2004)                               0.421685           110
# Usual Suspects, The (1995)                             0.411700           204
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (...     0.402193           120
# Eternal Sunshine of the Spotless Mind (2004)           0.401534           131
# Reservoir Dogs (1992)                                  0.394687           131
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)              0.391141           177
# Godfather, The (1972)                                  0.364778           192
# One Flew Over the Cuckoo's Nest (1975)                 0.361062           133
# Léon: The Professional (a.k.a. The Professional...     0.347574           133
# Silence of the Lambs, The (1991)                       0.345282           279
# Up (2009)                                              0.331295           105
# Matrix, The (1999)                                     0.330602           278
# Apocalypse Now (1979)                                  0.328592           107
# Aliens (1986)                                          0.322450           126
# Departed, The (2006)                                   0.306734           107
# Seven (a.k.a. Se7en) (1995)                            0.288502           203
# Memento (2000)                                         0.279844           159
# Donnie Darko (2001)                                    0.265083           109
# Ace Ventura: Pet Detective (1994)                      0.262937           161
# American History X (1998)                              0.262790           129
# Clerks (1994)                                          0.259111           104

# %% [markdown]
# ### Recommendation System for New User

# %%
df_ratings.head(2000)
# Out:
#       userId  movieId  rating
# 0          1        1     4.0
# 1          1        3     4.0
# 2          1        6     4.0
# 3          1       47     5.0
# 4          1       50     5.0
# ...      ...      ...     ...
# 1995      18     5944     2.5
# 1996      18     5952     3.5
# 1997      18     5956     4.0
# 1998      18     5989     4.0
# 1999      18     5995     4.5
#
# [2000 rows x 3 columns]

# %%
user_rating = [{'userId': 18, 'movieId': 5944, 'rating': '2.5'},
 {'userId': 18, 'movieId': 5952, 'rating': '3.5'},
 {'userId': 18, 'movieId': 5956, 'rating': '4.0'},
 {'userId': 18, 'movieId': 5989, 'rating': '4.0'},
 {'userId': 18, 'movieId': 5995, 'rating': '4.5'}]

# %%
new_ratings_df = df_ratings.append(user_rating,ignore_index=True)
new_data = Dataset.load_from_df(new_ratings_df,reader)

# %%
svd_ = SVD(n_factors= 50, reg_all=0.05)
svd_.fit(new_data.build_full_trainset())

# %%
list_of_movies = []
for m_id in df_ratings['movieId'].unique():
    list_of_movies.append( (m_id,svd_.predict(1000,m_id)[3]))

# %%
ranked_movies = sorted(list_of_movies, key=lambda x:x[1], reverse=True)

# %%
def recommended_movies(user_ratings,movie_title_df,n):
        for idx, rec in enumerate(user_ratings):
            title = movie_title_df.loc[movie_title_df['movieId'] == int(rec[0])]['title']
            print('Recommendation # ', idx+1, ': ', title, '\n')
            n-= 1
            if n == 0:
                break
            
recommended_movies(ranked_movies,df_movies,5)
# Out:
# Recommendation #  1 :  232      Shawshank Redemption, The (1994)
# 536      Shawshank Redemption, The (1994)
# 703      Shawshank Redemption, The (1994)
# 1051     Shawshank Redemption, The (1994)
# 1271     Shawshank Redemption, The (1994)
# 1404     Shawshank Redemption, The (1994)
# 1443     Shawshank Redemption, The (1994)
# 3801     Rear Window (1954)
# 4775     Rear Window (1954)
# 5302     Rear Window (1954)
# 8157     Rear Window (1954)
# 8645     Rear Window (1954)
# 13230    Rear Window (1954)
# 14259    Rear Window (1954)
# 15161    Rear Window (1954)
# 16244    Rear Window (1954)
# 18000    Rear Window (1954)
# 19654    Rear Window (1954)
# 19987    Rear Window (1954)
# 20750    Rear Window (1954)
# 22374    Rear Window (1954)
# 22752    Rear Window (1954)
# 23323    Rear Window (1954)
# 23894    Rear Window (1954)
# 24989    Rear Window (1954)
# 26227    Rear Window (1954)
# 27797    Rear Window (1954)
# 28120    Rear Window (1954)
# 28633    Rear Window (1954)
# 31599    Rear Window (1954)
# 32298    Rear Window (1954)
# 36435    Rear Window (1954)
# 37582    Rear Window (1954)
# 37996    Rear Window (1954)
# 39385    Rear Window (1954)
# 40629    Rear Window (1954)
# 41826    Rear Window (1954)
# 42221    Rear Window (1954)
# 43244    Rear Window (1954)
# 45998    Rear Window (1954)
# 46874    Rear Window (1954)
# 47744    Rear Window (1954)
# 47829    Rear Window (1954)
# 47939    Rear Window (1954)
# 48051    Rear Window (1954)
# 48820    Rear Window (1954)
# 49045    Rear Window (1954)
# 50247    Rear Window (1954)
# 50701    Rear Window (1954)
# 51029    Rear Window (1954)
# 51392    Rear Window (1954)
# 52035    Rear Window (1954)
# 52744    Rear Window (1954)
# 55501    Rear Window (1954)
# 56243    Rear Window (1954)
# 59337    Rear Window (1954)
# 60476    Rear Window (1954)
# 61870    Rear Window (1954)
# 62148    Rear Window (1954)
# 62631    Rear Window (1954)
# 65013    Rear Window (1954)
# 65597    Rear Window (1954)
# 65638    Rear Window (1954)
# 71161    Rear Window (1954)
# 71590    Rear Window (1954)
# 72187    Rear Window (1954)
# 72523    Rear Window (1954)
# 73287    Rear Window (1954)
# 75511    Rear Window (1954)
# 76076    Rear Window (1954)
# 77990    Rear Window (1954)
# 78308    Rear Window (1954)
# 78388    Rear Window (1954)
# 78586    Rear Window (1954)
# 79767    Rear Window (1954)
# 79807    Rear Window (1954)
# 88551    Rear Window (1954)
# 89998    Rear Window (1954)
# 90612    Rear Window (1954)
# 91775    Rear Window (1954)
# 92243    Rear Window (1954)
# 92949    Rear Window (1954)
# 95870    Rear Window (1954)
# 96287    Rear Window (1954)
# 97494    Rear Window (1954)
# 99588    Rear Window (1954)
# Name: title, dtype: object
#
# Recommendation #  5 :  192      Fight Club (1999)
# 458      Fight Club (1999)
# 1134     Fight Club (1999)
# 1479     Fight Club (1999)
# 1635     Fight Club (1999)
# 1734     Fight Club (1999)
# 1944     Fight Club (1999)
# 2829     Fight Club (1999)
# 3319     Fight Club (1999)
# 3679     Fight Club (1999)
# 4378     Fight Club (1999)
# 5217     Fight Club (1999)
# 5716     Fight Club (1999)
# 6185     Fight Club (1999)
# 6742     Fight Club (1999)
# 6957     Fight Club (1999)
# 7189     Fight Club (1999)
# 7797     Fight Club (1999)
# 8840     Fight Club (1999)
